# %%
import pandas as pd
import numpy as np

# %%
series = pd.date_range(start='2016-01-01', end='2017-01-01', freq='D')
df = pd.DataFrame(series)

# %%
df['nums'] = np.random.randint(0, 42, size=(len(series)))

# %%
mu, sigma = 50, 1 # mean and standard deviation
s = np.random.normal(mu, sigma, len(series))

# %%
df["none-stat"] = price_list

# %%
df["nums"].plot(x="test")
plt.show()

# %%
from matplotlib.pyplot import figure

figure(figsize=(16, 12), dpi=80)

# %%
fig, axs = plt.subplots(2)

axs[0].plot(df[0] ,df["nums"])
axs[0].set_title("Stationary time series")
axs[1].plot(df[0], df["none-stat"])
axs[1].set_title("None-Stationary time series")
fig.set_figheight(12)
fig.set_figwidth(12)

figure(figsize=(16, 12), dpi=80)
plt.show()

# %%
plt.plot(df[0] ,df["nums"])
plt.xlabel("Date")
plt.ylabel("Value")
plt.title("Stationary time series")
plt.show()

# %%
import pandas as pd
import numpy as np
import datetime
import yfinance as yf
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = yf.download("GME", start="2016-01-01", end="2017-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2015-12-31  28.430000  28.860001  28.030001  28.040001  21.640423  1696000
# 2016-01-04  27.040001  28.459999  27.010000  28.309999  21.848799  4330400
# 2016-01-05  28.590000  29.010000  28.059999  28.770000  22.203817  3416600
# 2016-01-06  28.230000  28.740000  27.440001  28.370001  21.895111  3756400
# 2016-01-07  28.120001  28.770000  27.740000  28.450001  21.956850  2662800
# ...               ...        ...        ...        ...        ...      ...
# 2016-12-23  25.559999  26.010000  25.320000  25.410000  20.664268  1977600
# 2016-12-27  25.410000  26.000000  25.400000  25.950001  21.103420  1596100
# 2016-12-28  25.790001  25.950001  25.080000  25.270000  20.550421  1716100
# 2016-12-29  25.240000  25.760000  25.240000  25.340000  20.607346  1714800
# 2016-12-30  25.420000  25.750000  25.219999  25.260000  20.542290  1747800
#
# [253 rows x 6 columns]

# %%
T = 367
count = 0
price_list = [10]

for y in range(T):
    if count == 367:
        break
    price = price_list[count]* (1 + np.random.normal(0, 0.1))
    price_list.append(price)
    count += 1

plt.plot(price_list)
plt.show()

# %%
price_list.pop()
# Out:
# 1.2694485407399554

# %%
len(price_list)
# Out:
# 367
