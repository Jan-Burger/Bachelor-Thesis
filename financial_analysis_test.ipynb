# %%
import yfinance as yf
import os

# %%
symbols = ["SPY", "GME", "AMC"]

# %%
data = yf.download("SPY", start="2021-05-01", end="2022-05-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-04-30  417.630005  418.540009  416.339996  417.299988  410.108307
# 2021-05-03  419.429993  419.839996  417.670013  418.200012  410.992828
# 2021-05-04  416.070007  416.600006  411.670013  415.619995  408.457275
# 2021-05-05  417.380005  417.630005  415.149994  415.750000  408.584991
# 2021-05-06  415.829987  419.209991  413.679993  419.070007  411.847870
# ...                ...         ...         ...         ...         ...
# 2022-04-25  423.670013  428.690002  418.839996  428.510010  426.666931
# 2022-04-26  425.829987  426.040009  416.070007  416.100006  414.310303
# 2022-04-27  417.239990  422.920013  415.010010  417.269989  415.475250
# 2022-04-28  422.290009  429.640015  417.600006  427.809998  425.969940
# 2022-04-29  423.589996  425.869995  411.209991  412.000000  410.227936
#
#                Volume
# Date
# 2021-04-30   85527000
# 2021-05-03   68128300
# 2021-05-04  101591200
# ...

# %%
data[["Close", "Adj Close"]].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# volume = total number of shares traded in a given time period -> sold and bought by someone
# adj. close = adjusted for stock splits for example

# %%
# forward fill and backward fill for missing values in general
# use friday to predict stock prices on monday and ignore weekends
# therefore, only use the dates were a stock price is available
# This means they are still equally spaced in trading time

# %%
#  net return formula in video on udemy
